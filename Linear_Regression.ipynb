# %% [markdown]
# ### <b>To predict the price of a house that has to be sold

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
indexlist = [i for i in range(1,5001)]

# %%
df = pd.read_csv('housing.csv', names=['Income', 'House Age', 'Number of Rooms','Number of Bedrooms','Population','Price','Address'], header=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Income              5000 non-null   float64
#  1   House Age           5000 non-null   float64
#  2   Number of Rooms     5000 non-null   float64
#  3   Number of Bedrooms  5000 non-null   float64
#  4   Population          5000 non-null   float64
#  5   Price               5000 non-null   float64
#  6   Address             5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.columns
# Out:
# Index(['Income', 'House Age', 'Number of Rooms', 'Number of Bedrooms',
#        'Population', 'Price', 'Address'],
#       dtype='object')

# %%
df.head()
# Out:
#          Income  House Age  Number of Rooms  Number of Bedrooms    Population  \
# 0  79545.458574   5.682861         7.009188                4.09  23086.800503
# 1  79248.642455   6.002900         6.730821                3.09  40173.072174
# 2  61287.067179   5.865890         8.512727                5.13  36882.159400
# 3  63345.240046   7.188236         5.586729                3.26  34310.242831
# 4  59982.197226   5.040555         7.839388                4.23  26354.109472
#
#           Price                                            Address
# 0  1.059034e+06  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  1.505891e+06  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  1.058988e+06  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3  1.260617e+06                          USS Barnett\nFPO AP 44820
# 4  6.309435e+05                         USNS Raymond\nFPO AE 09386

# %%
df.shape
# Out:
# (5000, 7)

# %%
df1 = df[['Income', 'House Age', 'Number of Rooms']][(df['House Age'] > 5.00) & (df['House Age']<9.00)]

# %%
# df1['']
df1['Number of Rooms'].mean()
# Out:
# 6.983033899249347

# %%
df1['Number of Rooms'].mean()
# Out:
# 6.983033899249347

# %% [markdown]
# #### <b> here the label is present in our dataset(price) and hence we will do supervised machine laerning

# %% [markdown]
# #### <b>we will make relation ship of prices with the different columns like how the size, population and income

# %%
plt.hist(df['Income'], bins=20) #most people's income
# Out:
# (array([  1.,   0.,   0.,   2.,  18.,  49., 111., 235., 406., 649., 763.,
#         838., 760., 544., 325., 188.,  66.,  36.,   7.,   2.]),
#  array([ 17796.63118954,  22291.88704895,  26787.14290835,  31282.39876776,
#          35777.65462716,  40272.91048657,  44768.16634597,  49263.42220538,
#          53758.67806478,  58253.93392419,  62749.18978359,  67244.445643  ,
#          71739.7015024 ,  76234.95736181,  80730.21322121,  85225.46908062,
#          89720.72494002,  94215.98079942,  98711.23665883, 103206.49251823,
#         107701.74837764]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df['House Age'], bins=20) # most houses are
# Out:
# (array([  5.,  10.,  38.,  65., 147., 239., 364., 505., 683., 653., 654.,
#         586., 417., 284., 181.,  93.,  53.,  16.,   6.,   1.]),
#  array([2.64430419, 2.98804338, 3.33178257, 3.67552177, 4.01926096,
#         4.36300016, 4.70673935, 5.05047854, 5.39421774, 5.73795693,
#         6.08169613, 6.42543532, 6.76917451, 7.11291371, 7.4566529 ,
#         7.8003921 , 8.14413129, 8.48787048, 8.83160968, 9.17534887,
#         9.51908807]),
#  <BarContainer object of 20 artists>)

# %%
# comparing price with other columns
for i in df.columns[:-2]:
    plt.scatter(df['Price'], df[i])
    plt.title(i + '  vs  Price')
    plt.xlabel('Price')
    plt.ylabel(i)
    plt.show()
    
# if these are showing linear regression like things then we can use linear Reg. 
# 1st and 2nd are showing linear regression
# number of rooms, income - not so much
# however popukation is somewhat related to the price

# %% [raw]
# import seaborn as sns
# sns.pairplot(df, kind='Reg')

# %%
#here we are going to segregate the labels anf features

# %%
df.columns
# Out:
# Index(['Income', 'House Age', 'Number of Rooms', 'Number of Bedrooms',
#        'Population', 'Price', 'Address'],
#       dtype='object')

# %%
x = df[['Income','House Age', 'Number of Rooms','Population']]

# %%
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.25, random_state = 10 )

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %% [raw]
# model.fit(xtrain,ytrain)

# %%
model.coef_ #this shows how much is price related to the features
# Out:
# array([2.13499040e+01, 1.64156159e+05, 4.72240159e+04, 1.53445491e+01])

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %% [raw]
# ######### from sklearn.metrics import

# %%
model.score(xtest,ytest)*100
# Out:
# 91.75444926964884
