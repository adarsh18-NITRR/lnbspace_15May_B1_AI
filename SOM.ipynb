# %%
#we can reduce the size of files from SOM and PCA
##OCR
##

# %%
## we make the model
# mimensions matter
# learning pace

# %%
from minisom import MiniSom
import matplotlib.pyplot as plt
import numpy as np

# %%
##to open the image - but we are concerned about the image data

# %%
img = plt.imread('bike.png')

# %%
def imshow(img):
    plt.imshow(img)
    plt.xticks([])
    # we are removing -
    plt.yticks([])
    plt.show()

# %%
imshow(img)

# %%
img.shape
# no of rows 
# no of columns
### if colors are same as in real life - then images are called true color images
# Out:
# (494, 741, 4)

# %%
# unit8 is information numbers of colors
# RGB
# 000  - White
# 255/255/255 - black
# 255/255/0 - Yellow

# (446, 914, 4), 3 value is number of layers - beacues theer are 3 layers of colors

# %%
pixel = np.reshape(img, (img.shape[0]*img.shape[1], img.shape[2]))

# %%
pixel.shape
# Out:
# (366054, 4)

# %%
som = MiniSom(x=3,y=3,input_len=4, sigma=0.1, learning_rate=0.2)

# %%
som.random_weights_init(pixel)
